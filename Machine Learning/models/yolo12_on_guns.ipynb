# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !nvidia-smi
# Out:
# Fri May 23 17:23:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow



from roboflow import Roboflow
rf = Roboflow(api_key="AHWDP3k8z64Bo3yFDwcl")
project = rf.workspace("instituto-superior-de-engenharia-de-coimbra-bgn4r").project("gun-surveilence")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Gun-Surveilence-1 in yolov12:: 100%|██████████| 972/972 [00:00<00:00, 7756.31it/s]

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v12.0/yolo12s.pt -O /content/yolo12s.pt
# Out:
# --2025-05-10 17:34:09--  https://github.com/ultralytics/assets/releases/download/v12.0/yolo12s.pt
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-10 17:34:10 ERROR 404: Not Found.

# %%
# !yolo task=detect \
      mode=train \
      model=yolo12s.pt \
      data=/content/Gun-Surveilence-1/data.yaml \
      epochs=20 \
      imgsz=640 \
      plots=True
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AHWDP3k8z64Bo3yFDwcl")
project = rf.workspace("crime-detection").project("guns_n_knives-h4bky")
version = project.version(3)
dataset = version.download("yolov12")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to guns_n_knives-3 in yolov12:: 100%|██████████| 19682/19682 [00:02<00:00, 8027.06it/s]

# %%
# !yolo task=detect \
      mode=train \
      model=yolo12m.pt \
      data=/content/guns_n_knives-3/data.yaml \
      epochs=30 \
      imgsz=640 \
      patience=20 \
      plots=True
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# VIEW MODEL TRANING CHARTS
from IPython.display import Image # Make sure you have this import statement at the beginning of your notebook or cell

# VIEW MODEL TRANING CHARTS
Image(filename=f'/content/runs/detect/train5/results.png', width=600)

# %%
# VALIDATION
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/Gun-Surveilence-1/data.yaml
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 893.9±277.0 MB/s, size: 26.7 KB)
# val: Scanning /content/Gun-Surveilence-1/valid/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.68it/s]
#                    all         20         21      0.966      0.952      0.977      0.631
#                    gun         20         21      0.966      0.952      0.977      0.631
# Speed: 0.3ms preprocess, 39.6ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")
model.predict(source=0, save=True,conf=0.4,show=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/runs/detect/train5/weights/best.pt /content/drive/MyDrive/
